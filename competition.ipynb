# %% [markdown]
# Silent data flows,
# Neural nets weave future dreams,
# Vectors guide the path.

# %%
              _______________________
             |                       |
             |     Generative AI     |
             |_______________________|
                     |       |
                     |       |
       ______________V_______V_____________
      |                                     |
      |           Vector Databases          |
      |_____________________________________|
                     |       |
                     |       |
           _________ V _______V_______
          |                           |
          |     The Future of Tech    |
          |___________________________|
